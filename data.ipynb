# %%
# !pip install pandas numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# ...

# %%
import pandas as pd
import random
from datetime import datetime, timedelta
import pytz

# %%
data = pd.read_csv('data/data.csv')
data
# Out:
#                                                   Title      Date  \
# 0     They said it is registration fee for birth cer...  14-10-20
# 1     Paid bribe for not having insurance during pan...  13-10-20
# 2                   Forced to pay bribe at KR Puram RTO  13-10-20
# 3            Forced to pay 100 rupees bribe for LL test  13-10-20
# 4     Misusing of power and traping people in false ...  13-10-20
# ...                                                 ...       ...
# 3468  I Paid Rs. 33 to Commercial Tax, Sales Tax, VA...  30-10-15
# 3469   I Paid Rs. 10 to Municipal Services in Jabalpur.  30-10-15
# 3470           I Paid Rs. 500 to Income Tax in Hingoli.  30-10-15
# 3471  I Paid Rs. 800 to Municipal Services in Achhnera.  30-10-15
# 3472  I Paid Rs. 16000 to Municipal Services in Mumbai.  29-10-15
#
#                     Location                      Department  Views  \
# 0        Bangalore,Karnataka         Births, Family and Care   1225
# ...

# %%
def add_random_time_to_dates(df, date_col='date'):
    moscow_tz = pytz.timezone('Europe/Moscow')
    df[date_col] = pd.to_datetime(df[date_col], errors='coerce')
    
    def random_timedelta():
        return timedelta(hours=random.randint(0, 23), minutes=random.randint(0, 59))
    
    df[date_col] = df[date_col].apply(lambda d: moscow_tz.localize(d + random_timedelta()) if not pd.isnull(d) else d)
    
    return df

# Assuming 'data' is your DataFrame and 'Date' is the name of your date column
data = add_random_time_to_dates(data, 'Date')
# Out:
# /tmp/ipykernel_22395/3359724450.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

# %%
data.drop(['Views'], axis=1, inplace=True)

# %%
data.columns = ['title', 'date', 'location', 'department', 'amount']
# data['id'] = 0
data['encrypted_user_id'] = 0
data['description'] = '-'
new_column_order = ['encrypted_user_id', 'title', 'date', 'location', 'department', 'amount', 'description']
data = data[new_column_order]
data.head()
# Out:
#    encrypted_user_id                                              title  \
# 0                  0  They said it is registration fee for birth cer...
# 1                  0  Paid bribe for not having insurance during pan...
# 2                  0                Forced to pay bribe at KR Puram RTO
# 3                  0         Forced to pay 100 rupees bribe for LL test
# 4                  0  Misusing of power and traping people in false ...
#
#                        date             location  \
# 0 2020-10-14 07:57:00+03:00  Bangalore,Karnataka
# 1 2020-10-13 14:38:00+03:00  Bangalore,Karnataka
# 2 2020-10-13 04:34:00+03:00  Bangalore,Karnataka
# 3 2020-10-13 18:22:00+03:00  Bangalore,Karnataka
# 4 2020-10-13 10:42:00+03:00          Siwan,Bihar
#
#                        department  amount description
# 0         Births, Family and Care     400           -
# 1               Vehicle Insurance     350           -
# 2  Driving and Transport Business     100           -
# ...
